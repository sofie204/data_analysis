# %% [markdown]
# # Rental Dataset

# %% [markdown]
# This notebook is a continuation to nb01, and here I will take some time to verify all my current basic assumptions about this dataset which include:
#
# - The most expensive borough to rent apartments is in Manhattan -- most expensive neighborhood within that borough is Noho
# - The least expensive borough to rent apartments is in Staten Island (due to the fact that one has to travel there by ferry as compared with the rest of NYC)
# - The more bedrooms an apartment has, the more pricey it is
# - It costs more money to rent in the newer builds
# - Is there a correlation between the mins to subway and the rental prices ? and the boroughs as well? (how do these three interact with one another)
# - What proportion of the market has things such as a gym, doorman, roofdeck and so on. Which areas are these located and how to these affect the rental prices.
#     - When looking at these keep common sense in mind, common sense meaning in NYC we know that the weather is quite crap a decent chunk of the time so does it make sense to pay higher for an apartment with a roofdeck knowing that you won't be able to use it often because when it is indeed nice outside one would most likely want to go out with friends to actual restaurants as opposed to your apartments roofdeck, that is unless one enjoys a good barbeque.

# %% [markdown]
# ## Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# printing out the version of pandas used for this analysis
print(pd.__version__)
# Out:
# 1.2.1

# %% [markdown]
# ## Get Data

# %%
rental_df = pd.read_csv('rentals.csv')
