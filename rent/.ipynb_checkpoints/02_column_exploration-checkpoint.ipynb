# %% [markdown]
# # Rental Dataset

# %% [markdown]
# ## Scope: The goal of this notebook is to explore and understand each and every column in this dataset.
#
# This seems like a daunting task since there are 20 columns, though there is luck in the sense that all columns are clean and don't require further processing. For most of the columns, there will be basic exploration (since future notebooks will deal with relationships between two columns in depth) and for some others such as `rent` we can expect deeper analysis in this notebook.

# %% [markdown]
# ## Import Relevant Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# printing out the version of pandas used for this analysis
print(pd.__version__)
# Out:
# 1.2.1

# %% [markdown]
# ## Get Data

# %%
rental_df = pd.read_csv('new_rental')

# %%
rental_df.head()
# Out:
#    Unnamed: 0  rental_id  building_id   rent  bedrooms  bathrooms  size_sqft  \
# 0           0       1545     44518357   2550       0.0          1        480
# 1           1       2472     94441623  11500       2.0          2       2000
# 2           2      10234     87632265   3000       3.0          1       1000
# 3           3       2919     76909719   4500       1.0          1        916
# 4           4       2790     92953520   4795       1.0          1        975
#
#    min_to_subway  floor  building_age_yrs  ... has_roofdeck has_washer_dryer  \
# 0              9    2.0                17  ...          yes               no
# 1              4    1.0                96  ...           no               no
# 2              4    1.0               106  ...           no               no
# 3              2   51.0                29  ...          yes               no
# 4              3    8.0                31  ...           no               no
#
#   has_doorman has_elevator has_dishwasher has_patio has_gym  \
# 0          no          yes            yes        no     yes
# 1          no           no             no        no      no
# 2          no           no             no        no      no
# 3         yes          yes            yes        no      no
# 4         yes          yes            yes        no     yes
#
#         neighborhood            submarket    borough
# 0    Upper East Side  All Upper East Side  Manhattan
# 1  Greenwich Village         All Downtown  Manhattan
# 2            Astoria     Northwest Queens     Queens
# 3            Midtown          All Midtown  Manhattan
# 4  Greenwich Village         All Downtown  Manhattan
#
# [5 rows x 21 columns]

# %%
# From what can be seen above, there is an unwanted index column and this can be gotten rid of
rental_df = pd.read_csv('new_rental', index_col =0)

# %%
rental_df.head()
# Out:
#    rental_id  building_id   rent  bedrooms  bathrooms  size_sqft  \
# 0       1545     44518357   2550       0.0          1        480
# 1       2472     94441623  11500       2.0          2       2000
# 2      10234     87632265   3000       3.0          1       1000
# 3       2919     76909719   4500       1.0          1        916
# 4       2790     92953520   4795       1.0          1        975
#
#    min_to_subway  floor  building_age_yrs no_fee has_roofdeck  \
# 0              9    2.0                17    yes          yes
# 1              4    1.0                96     no           no
# 2              4    1.0               106     no           no
# 3              2   51.0                29     no          yes
# 4              3    8.0                31     no           no
#
#   has_washer_dryer has_doorman has_elevator has_dishwasher has_patio has_gym  \
# 0               no          no          yes            yes        no     yes
# 1               no          no           no             no        no      no
# 2               no          no           no             no        no      no
# 3               no         yes          yes            yes        no      no
# 4               no         yes          yes            yes        no     yes
#
#         neighborhood            submarket    borough
# 0    Upper East Side  All Upper East Side  Manhattan
# 1  Greenwich Village         All Downtown  Manhattan
# 2            Astoria     Northwest Queens     Queens
# 3            Midtown          All Midtown  Manhattan
# 4  Greenwich Village         All Downtown  Manhattan

# %%
rental_df.tail()
# Out:
#       rental_id  building_id  rent  bedrooms  bathrooms  size_sqft  \
# 4995       1964     73060494  2650       1.0          1        686
# 4996       5686     92994390  6675       2.0          2        988
# 4997       9679      7689663  1699       0.0          1        250
# 4998       5188     62828354  3475       1.0          1        651
# 4999       4718     67659586  4500       1.0          1        816
#
#       min_to_subway  floor  building_age_yrs no_fee has_roofdeck  \
# 4995              9    4.0                 3    yes           no
# 4996              5   10.0                 9    yes          yes
# 4997              2    5.0                96     no           no
# 4998              6    5.0                14    yes           no
# 4999              4   11.0                 9     no          yes
#
#      has_washer_dryer has_doorman has_elevator has_dishwasher has_patio  \
# 4995               no          no           no             no        no
# 4996              yes         yes          yes            yes        no
# 4997               no          no           no             no        no
# 4998              yes         yes          yes            yes        no
# 4999              yes         yes          yes             no       yes
#
#      has_gym  neighborhood         submarket    borough
# 4995      no       Astoria  Northwest Queens     Queens
# 4996     yes       Tribeca      All Downtown  Manhattan
# 4997      no  Little Italy      All Downtown  Manhattan
# 4998     yes  Midtown West       All Midtown  Manhattan
# 4999     yes       Tribeca      All Downtown  Manhattan

# %%
rental_df.sample(10)
# Out:
#       rental_id  building_id   rent  bedrooms  bathrooms  size_sqft  \
# 4718       6909     87356164   3988       1.0          1        630
# 2285       2250     62828586  11000       2.0          3       1607
# 4266       6190     79496356   3995       1.5          1        900
# 2651       4994     15555409   2300       1.0          1        500
# 3000       6796     11790470   1825       1.0          1        773
# 2798       4704     73605280   3675       1.0          1        850
# 4020       3679     95366382   1800       2.0          1        920
# 630        2961     57174723   2600       0.0          1        570
# 4034       2910     88062922   3800       1.0          1        700
# 3215       2134      6434691  15000       3.0          2       1700
#
#       min_to_subway  floor  building_age_yrs no_fee has_roofdeck  \
# 4718             12   14.0                 4    yes           no
# 2285              5    8.0                88     no          yes
# 4266             12   24.0                36    yes           no
# 2651              2    4.0               116     no           no
# 3000             13    5.0                60    yes           no
# 2798              4    4.0                76     no          yes
# 4020              5    4.0                62     no           no
# 630               2   19.0                13     no           no
# 4034             10    9.0                 9    yes           no
# 3215              6    7.0                12     no           no
#
#      has_washer_dryer has_doorman has_elevator has_dishwasher has_patio  \
# 4718               no          no           no             no        no
# 2285              yes         yes          yes            yes        no
# 4266               no          no          yes            yes        no
# 2651               no          no           no             no        no
# 3000               no          no           no            yes        no
# 2798              yes         yes           no            yes        no
# 4020               no          no           no             no        no
# 630                no          no           no             no        no
# 4034              yes          no           no            yes        no
# 3215               no          no           no             no        no
#
#      has_gym        neighborhood            submarket    borough
# 4718      no        Midtown West          All Midtown  Manhattan
# 2285     yes     Upper East Side  All Upper East Side  Manhattan
# 4266      no     Upper East Side  All Upper East Side  Manhattan
# 2651      no     Upper East Side  All Upper East Side  Manhattan
# 3000      no        Forest Hills       Central Queens     Queens
# 2798     yes        East Village         All Downtown  Manhattan
# 4020      no           Rego Park       Central Queens     Queens
# 630       no  Financial District         All Downtown  Manhattan
# 4034      no       Gramercy Park         All Downtown  Manhattan
# 3215      no     Lower East Side         All Downtown  Manhattan

# %%
list(rental_df.columns)
# Out:
# ['rental_id',
#  'building_id',
#  'rent',
#  'bedrooms',
#  'bathrooms',
#  'size_sqft',
#  'min_to_subway',
#  'floor',
#  'building_age_yrs',
#  'no_fee',
#  'has_roofdeck',
#  'has_washer_dryer',
#  'has_doorman',
#  'has_elevator',
#  'has_dishwasher',
#  'has_patio',
#  'has_gym',
#  'neighborhood',
#  'submarket',
#  'borough']

# %% [markdown]
# As stated in the scope, the goal of this notebook is to got through each column and analyze the data, see what information can be gleaned by taking a look.

# %% [markdown]
# ## `rental_id`

# %%
rental_df.rental_id.dtype
# Out:
# dtype('int64')

# %%
rental_df.rental_id.nunique()
# Out:
# 5000

# %% [markdown]
# What the code in the cells above have shown is that there are 5000 individual unique `rental_id` values. It seems as though this column is simply there in order to identify the apartment buildings. My assumption is that each apartment has a rental id for administrative purposes

# %% [markdown]
# ## `building_id`
